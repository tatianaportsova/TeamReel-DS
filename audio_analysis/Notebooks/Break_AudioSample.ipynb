# %% [markdown]
# ##  Get the lecture audio and break it into smaller parts

# %%
#pip install pydub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import moviepy.editor
video = moviepy.editor.VideoFileClip('zoom_0.mp4')
audio = video.audio
audio.write_audiofile('lecture_audio.wav')
# Out:
# chunk:   0%|          | 38/145089 [00:00<11:19, 213.44it/s, now=None]
# MoviePy - Writing audio in lecture_audio.wav
# MoviePy - Done.

# %%
from pydub import AudioSegment
from pydub.utils import make_chunks
import os

myaudio = AudioSegment.from_file("lecture_audio.wav" , "wav") 
chunk_length_ms = 4000 # pydub calculates in millisec
chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of 4 sec

#Export all of the individual chunks as wav files
path = "lecture_chunks/"
try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)

for i, chunk in enumerate(chunks):
    chunk_name = "lecture_chunks/chunk{0}.wav".format(i)
    print ("exporting", chunk_name)
    chunk.export(chunk_name, format="wav")
# Out:
# Successfully created the directory lecture_chunks/
# exporting lecture_chunks/chunk0.wav
# exporting lecture_chunks/chunk1.wav
# exporting lecture_chunks/chunk2.wav
# exporting lecture_chunks/chunk3.wav
# exporting lecture_chunks/chunk4.wav
# exporting lecture_chunks/chunk5.wav
# exporting lecture_chunks/chunk6.wav
# exporting lecture_chunks/chunk7.wav
# exporting lecture_chunks/chunk8.wav
# exporting lecture_chunks/chunk9.wav
# exporting lecture_chunks/chunk10.wav
# exporting lecture_chunks/chunk11.wav
# exporting lecture_chunks/chunk12.wav
# exporting lecture_chunks/chunk13.wav
# exporting lecture_chunks/chunk14.wav
# exporting lecture_chunks/chunk15.wav
# exporting lecture_chunks/chunk16.wav
# exporting lecture_chunks/chunk17.wav
# exporting lecture_chunks/chunk18.wav
# exporting lecture_chunks/chunk19.wav
# exporting lecture_chunks/chunk20.wav
# exporting lecture_chunks/chunk21.wav
# exporting lecture_chunks/chunk22.wav
# exporting lecture_chunks/chunk23.wav
# ...
